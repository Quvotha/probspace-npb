# %%
import os
import os.path
import pickle

import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
# from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, confusion_matrix

# %%
NOTE = '全特徴量を使用したSVM. class_weight を指定。Cは0.1'

N = 5
CV = f'Stratified-Kfold(K={N})'

notebook_name = '014_SVM_balanced_C01'
OUTPUT_DIR = os.path.basename(notebook_name)
SUB_FILENAME = notebook_name[:3] + '_submission.csv'
assert(SUB_FILENAME not in pd.read_csv('submissions.csv').filename.tolist())
print(SUB_FILENAME, OUTPUT_DIR)
if not os.path.isdir(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

SEED = 1
CATEGORICAL_FEATURES =  [
        'batterID', 'pitcherID', 'Match',
        'isBatterHandLeft', 'isPitcherHandLeft', 'isBatterPitcher',
        'isBottom', 'batterTeam', 'pitcherTeam'
    ]
# Out:
# 014_submission.csv 014_SVM_balanced_C01

# %%
def get_estimator(categorical_features, discrete_features):
    discrete_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ])
    preprocessor = ColumnTransformer(
        transformers=[
            ('discrete', discrete_transformer, discrete_features),
            ('categorical', 'passthrough', categorical_features),
        ]
    )
    return Pipeline(
        steps=[
            ('preprocessor', preprocessor),
            ('estimator', SVC(C=0.1, random_state=SEED, class_weight='balanced'))
        ]
    )

# %%
train = pd.read_csv(os.path.join('001_EDA', 'train_data_preprocessed.csv'))
test = pd.read_csv(os.path.join('001_EDA', 'test_data_preprocessed.csv'))

# %%
for c in CATEGORICAL_FEATURES:
    assert(train[c].isin(test[c]).sum() == train.shape[0])
    assert(test[c].isin(train[c]).sum() == test.shape[0])

train = pd.get_dummies(train, columns=CATEGORICAL_FEATURES, drop_first=True)
test = pd.get_dummies(test, columns=CATEGORICAL_FEATURES, drop_first=True)

assert(set(train.columns.tolist()) - set(test.columns.tolist()) == {'y'})
assert(set(test.columns.tolist()) - set(train.columns.tolist()) == set())

# %%
categorical_features = []
for c in CATEGORICAL_FEATURES:
    categorical_features += [c_ for c_ in train.columns if c_.startswith(f'{c}_')]
categorical_features
# Out:
# ['batterID_0',
#  'batterID_2',
#  'batterID_5',
#  'batterID_9',
#  'batterID_11',
#  'batterID_12',
#  'batterID_15',
#  'batterID_18',
#  'batterID_19',
#  'batterID_21',
#  'batterID_22',
#  'batterID_26',
#  'batterID_27',
#  'batterID_28',
#  'batterID_29',
#  'batterID_31',
#  'batterID_34',
#  'batterID_36',
#  'batterID_37',
#  'batterID_39',
#  'batterID_42',
#  'batterID_45',
#  'batterID_47',
#  'batterID_50',
#  'batterID_55',
#  'batterID_56',
#  'batterID_58',
#  'batterID_60',
#  'batterID_67',
#  'batterID_70',
#  'batterID_72',
#  'batterID_73',
#  'batterID_75',
#  'batterID_80',
#  'batterID_82',
#  'batterID_84',
#  'batterID_85',
#  'batterID_87',
#  'batterID_89',
#  'batterID_91',
#  'batterID_98',
#  'batterID_102',
#  'batterID_103',
#  'batterID_105',
#  'batterID_106',
#  'batterID_111',
#  'batterID_112',
#  'batterID_114',
#  'batterID_117',
#  'batterID_118',
#  'batterID_120',
#  'batterID_121',
#  'batterID_125',
#  'batterID_127',
#  'batterID_128',
#  'batterID_130',
#  'batterID_132',
#  'batterID_134',
#  'batterID_135',
#  'batterID_137',
#  'batterID_138',
#  'batterID_140',
#  'batterID_145',
#  'batterID_147',
#  'batterID_148',
#  'batterID_149',
#  'batterID_150',
#  'batterID_151',
#  'batterID_153',
#  'batterID_156',
#  'batterID_164',
#  'batterID_167',
#  'batterID_168',
#  'batterID_171',
#  'batterID_176',
#  'batterID_177',
#  'batterID_179',
#  'batterID_182',
#  'batterID_183',
#  'batterID_184',
#  'batterID_185',
#  'batterID_188',
#  'batterID_191',
#  'batterID_192',
#  'batterID_193',
#  'batterID_196',
#  'batterID_199',
#  'batterID_201',
#  'batterID_203',
#  'batterID_209',
#  'batterID_212',
#  'batterID_216',
#  'batterID_217',
#  'batterID_219',
#  'batterID_220',
#  'batterID_224',
#  'batterID_225',
#  'batterID_226',
#  'batterID_228',
#  'batterID_229',
#  'batterID_230',
#  'batterID_236',
#  'batterID_237',
#  'batterID_238',
#  'batterID_239',
#  'batterID_247',
#  'batterID_250',
#  'batterID_253',
#  'batterID_261',
#  'batterID_262',
#  'batterID_263',
#  'batterID_264',
#  'batterID_269',
#  'batterID_271',
#  'batterID_273',
#  'batterID_274',
#  'batterID_276',
#  'batterID_281',
#  'batterID_283',
#  'batterID_286',
#  'batterID_287',
#  'batterID_293',
#  'batterID_295',
#  'batterID_296',
#  'batterID_298',
#  'batterID_301',
#  'batterID_303',
#  'batterID_305',
#  'batterID_307',
#  'batterID_308',
#  'batterID_311',
#  'batterID_313',
#  'batterID_321',
#  'batterID_324',
#  'batterID_325',
#  'batterID_327',
#  'batterID_328',
#  'batterID_329',
#  'batterID_330',
#  'batterID_333',
#  'batterID_335',
#  'batterID_340',
#  'batterID_349',
#  'batterID_352',
#  'batterID_355',
#  'batterID_357',
#  'batterID_362',
#  'batterID_367',
#  'batterID_368',
#  'batterID_374',
#  'batterID_380',
#  'batterID_381',
#  'batterID_391',
#  'batterID_392',
#  'batterID_401',
#  'batterID_402',
#  'batterID_408',
#  'batterID_412',
#  'batterID_416',
#  'batterID_417',
#  'batterID_418',
#  'batterID_420',
#  'batterID_423',
#  'batterID_427',
#  'batterID_430',
#  'batterID_431',
#  'batterID_432',
#  'batterID_433',
#  'batterID_437',
#  'batterID_443',
#  'batterID_444',
#  'batterID_446',
#  'batterID_449',
#  'batterID_451',
#  'batterID_455',
#  'batterID_458',
#  'batterID_462',
#  'batterID_469',
#  'batterID_472',
#  'batterID_475',
#  'batterID_479',
#  'batterID_480',
#  'batterID_485',
#  'batterID_488',
#  'batterID_490',
#  'batterID_492',
#  'batterID_495',
#  'batterID_496',
#  'batterID_498',
#  'batterID_500',
#  'batterID_505',
#  'batterID_509',
#  'batterID_510',
#  'batterID_511',
#  'batterID_512',
#  'batterID_516',
#  'batterID_523',
#  'batterID_535',
#  'batterID_537',
#  'batterID_540',
#  'batterID_544',
#  'batterID_546',
#  'batterID_551',
#  'batterID_555',
#  'batterID_556',
#  'batterID_557',
#  'batterID_558',
#  'batterID_559',
#  'batterID_562',
#  'batterID_565',
#  'batterID_567',
#  'batterID_572',
#  'batterID_574',
#  'batterID_580',
#  'batterID_582',
#  'batterID_584',
#  'batterID_590',
#  'batterID_601',
#  'batterID_612',
#  'batterID_615',
#  'batterID_619',
#  'batterID_620',
#  'batterID_624',
#  'batterID_628',
#  'batterID_636',
#  'batterID_638',
#  'batterID_642',
#  'batterID_644',
#  'batterID_646',
#  'batterID_654',
#  'batterID_655',
#  'batterID_661',
#  'pitcherID_2',
#  'pitcherID_4',
#  'pitcherID_6',
#  'pitcherID_7',
#  'pitcherID_10',
#  'pitcherID_16',
#  'pitcherID_25',
#  'pitcherID_29',
#  'pitcherID_31',
#  'pitcherID_35',
#  'pitcherID_39',
#  'pitcherID_45',
#  'pitcherID_46',
#  'pitcherID_48',
#  'pitcherID_49',
#  'pitcherID_52',
#  'pitcherID_55',
#  'pitcherID_58',
#  'pitcherID_59',
#  'pitcherID_64',
#  'pitcherID_77',
#  'pitcherID_81',
#  'pitcherID_82',
#  'pitcherID_94',
#  'pitcherID_97',
#  'pitcherID_101',
#  'pitcherID_102',
#  'pitcherID_107',
#  'pitcherID_110',
#  'pitcherID_114',
#  'pitcherID_116',
#  'pitcherID_119',
#  'pitcherID_120',
#  'pitcherID_123',
#  'pitcherID_128',
#  'pitcherID_130',
#  'pitcherID_131',
#  'pitcherID_136',
#  'pitcherID_137',
#  'pitcherID_143',
#  'pitcherID_146',
#  'pitcherID_147',
#  'pitcherID_155',
#  'pitcherID_156',
#  'pitcherID_158',
#  'pitcherID_169',
#  'pitcherID_175',
#  'pitcherID_181',
#  'pitcherID_182',
#  'pitcherID_185',
#  'pitcherID_188',
#  'pitcherID_190',
#  'pitcherID_191',
#  'pitcherID_196',
#  'pitcherID_199',
#  'pitcherID_200',
#  'pitcherID_210',
#  'pitcherID_211',
#  'pitcherID_218',
#  'pitcherID_222',
#  'pitcherID_223',
#  'pitcherID_224',
#  'pitcherID_225',
#  'pitcherID_227',
#  'pitcherID_231',
#  'pitcherID_234',
#  'pitcherID_240',
#  'pitcherID_241',
#  'pitcherID_245',
#  'pitcherID_247',
#  'pitcherID_262',
#  'pitcherID_265',
#  'pitcherID_267',
#  'pitcherID_269',
#  'pitcherID_270',
#  'pitcherID_274',
#  'pitcherID_275',
#  'pitcherID_280',
#  'pitcherID_282',
#  'pitcherID_288',
#  'pitcherID_293',
#  'pitcherID_294',
#  'pitcherID_297',
#  'pitcherID_298',
#  'pitcherID_305',
#  'pitcherID_311',
#  'pitcherID_320',
#  'pitcherID_322',
#  'pitcherID_325',
#  'pitcherID_331',
#  'pitcherID_333',
#  'pitcherID_334',
#  'pitcherID_336',
#  'pitcherID_341',
#  'pitcherID_348',
#  'pitcherID_350',
#  'pitcherID_351',
#  'pitcherID_358',
#  'pitcherID_359',
#  'pitcherID_363',
#  'pitcherID_365',
#  'pitcherID_369',
#  'pitcherID_371',
#  'pitcherID_373',
#  'pitcherID_376',
#  'pitcherID_377',
#  'pitcherID_383',
#  'pitcherID_385',
#  'pitcherID_387',
#  'pitcherID_390',
#  'pitcherID_393',
#  'pitcherID_394',
#  'pitcherID_395',
#  'pitcherID_397',
#  'pitcherID_400',
#  'pitcherID_403',
#  'pitcherID_405',
#  'pitcherID_407',
#  'pitcherID_409',
#  'pitcherID_413',
#  'pitcherID_419',
#  'pitcherID_426',
#  'pitcherID_434',
#  'pitcherID_435',
#  'pitcherID_438',
#  'pitcherID_440',
#  'pitcherID_441',
#  'pitcherID_447',
#  'pitcherID_448',
#  'pitcherID_459',
#  'pitcherID_460',
#  'pitcherID_463',
#  'pitcherID_467',
#  'pitcherID_474',
#  'pitcherID_476',
#  'pitcherID_477',
#  'pitcherID_478',
#  'pitcherID_481',
#  'pitcherID_483',
#  'pitcherID_493',
#  'pitcherID_494',
#  'pitcherID_501',
#  'pitcherID_504',
#  'pitcherID_506',
#  'pitcherID_507',
#  'pitcherID_517',
#  'pitcherID_519',
#  'pitcherID_520',
#  'pitcherID_522',
#  'pitcherID_524',
#  'pitcherID_528',
#  'pitcherID_532',
#  'pitcherID_539',
#  'pitcherID_542',
#  'pitcherID_550',
#  'pitcherID_552',
#  'pitcherID_553',
#  'pitcherID_560',
#  'pitcherID_563',
#  'pitcherID_575',
#  'pitcherID_578',
#  'pitcherID_579',
#  'pitcherID_587',
#  'pitcherID_592',
#  'pitcherID_593',
#  'pitcherID_595',
#  'pitcherID_596',
#  'pitcherID_597',
#  'pitcherID_602',
#  'pitcherID_607',
#  'pitcherID_611',
#  'pitcherID_616',
#  'pitcherID_617',
#  'pitcherID_618',
#  'pitcherID_623',
#  'pitcherID_629',
#  'pitcherID_630',
#  'pitcherID_634',
#  'pitcherID_635',
#  'pitcherID_640',
#  'pitcherID_641',
#  'pitcherID_647',
#  'pitcherID_650',
#  'pitcherID_651',
#  'pitcherID_657',
#  'pitcherID_662',
#  'Match_0',
#  'Match_1',
#  'Match_2',
#  'Match_3',
#  'Match_6',
#  'Match_7',
#  'Match_18',
#  'Match_25',
#  'Match_28',
#  'Match_29',
#  'Match_34',
#  'Match_38',
#  'Match_53',
#  'Match_54',
#  'Match_57',
#  'Match_58',
#  'Match_59',
#  'Match_62',
#  'Match_69',
#  'Match_70',
#  'Match_72',
#  'Match_77',
#  'Match_83',
#  'Match_88',
#  'Match_93',
#  'Match_115',
#  'Match_116',
#  'Match_120',
#  'Match_121',
#  'Match_137',
#  'Match_138',
#  'Match_140',
#  'Match_142',
#  'Match_143',
#  'Match_145',
#  'Match_147',
#  'Match_149',
#  'Match_150',
#  'Match_174',
#  'Match_176',
#  'Match_186',
#  'Match_187',
#  'Match_188',
#  'Match_191',
#  'Match_192',
#  'Match_198',
#  'Match_199',
#  'Match_203',
#  'Match_204',
#  'Match_224',
#  'Match_239',
#  'Match_240',
#  'Match_244',
#  'Match_245',
#  'Match_257',
#  'Match_262',
#  'Match_276',
#  'Match_279',
#  'Match_289',
#  'Match_300',
#  'Match_302',
#  'Match_303',
#  'Match_305',
#  'Match_306',
#  'Match_307',
#  'Match_326',
#  'Match_327',
#  'Match_333',
#  'Match_334',
#  'Match_338',
#  'Match_339',
#  'Match_362',
#  'Match_376',
#  'Match_377',
#  'Match_378',
#  'Match_379',
#  'Match_380',
#  'Match_382',
#  'Match_384',
#  'Match_386',
#  'Match_387',
#  'Match_389',
#  'Match_392',
#  'Match_430',
#  'Match_431',
#  'Match_435',
#  'Match_438',
#  'Match_468',
#  'Match_469',
#  'Match_470',
#  'Match_471',
#  'Match_472',
#  'Match_473',
#  'Match_475',
#  'Match_492',
#  'Match_498',
#  'Match_523',
#  'Match_524',
#  'Match_525',
#  'Match_526',
#  'Match_529',
#  'Match_531',
#  'Match_532',
#  'Match_599',
#  'Match_602',
#  'Match_604',
#  'Match_605',
#  'Match_613',
#  'Match_621',
#  'Match_623',
#  'Match_630',
#  'Match_649',
#  'Match_650',
#  'Match_671',
#  'Match_672',
#  'Match_673',
#  'Match_674',
#  'Match_680',
#  'Match_681',
#  'Match_729',
#  'Match_752',
#  'Match_753',
#  'Match_754',
#  'Match_756',
#  'Match_771',
#  'Match_777',
#  'Match_778',
#  'Match_780',
#  'Match_783',
#  'Match_784',
#  'Match_785',
#  'Match_786',
#  'Match_791',
#  'Match_796',
#  'Match_797',
#  'Match_798',
#  'Match_799',
#  'Match_800',
#  'Match_802',
#  'Match_803',
#  'Match_804',
#  'Match_872',
#  'Match_888',
#  'Match_889',
#  'Match_890',
#  'Match_891',
#  'Match_961',
#  'Match_962',
#  'Match_963',
#  'Match_975',
#  'Match_976',
#  'Match_977',
#  'Match_978',
#  'Match_981',
#  'Match_990',
#  'Match_999',
#  'Match_1000',
#  'Match_1018',
#  'Match_1019',
#  'Match_1020',
#  'Match_1021',
#  'Match_1022',
#  'Match_1023',
#  'Match_1024',
#  'Match_1025',
#  'Match_1027',
#  'Match_1028',
#  'Match_1058',
#  'Match_1065',
#  'Match_1075',
#  'Match_1112',
#  'Match_1113',
#  'Match_1114',
#  'Match_1115',
#  'Match_1117',
#  'Match_1119',
#  'Match_1153',
#  'Match_1192',
#  'Match_1193',
#  'Match_1194',
#  'Match_1195',
#  'Match_1197',
#  'Match_1198',
#  'Match_1213',
#  'Match_1216',
#  'Match_1259',
#  'Match_1267',
#  'Match_1273',
#  'Match_1292',
#  'Match_1296',
#  'Match_1315',
#  'Match_1317',
#  'Match_1318',
#  'Match_1319',
#  'Match_1320',
#  'Match_1321',
#  'Match_1374',
#  'Match_1375',
#  'Match_1376',
#  'Match_1377',
#  'Match_1378',
#  'Match_1436',
#  'Match_1437',
#  'Match_1440',
#  'Match_1443',
#  'Match_1446',
#  'Match_1453',
#  'Match_1455',
#  'Match_1471',
#  'Match_1488',
#  'Match_1490',
#  'Match_1539',
#  'Match_1540',
#  'Match_1541',
#  'Match_1542',
#  'Match_1550',
#  'Match_1556',
#  'Match_1588',
#  'Match_1589',
#  'Match_1606',
#  'Match_1608',
#  'Match_1620',
#  'Match_1627',
#  'Match_1633',
#  'Match_1634',
#  'Match_1650',
#  'Match_1857',
#  'Match_1858',
#  'Match_1859',
#  'Match_1865',
#  'Match_1867',
#  'Match_1872',
#  'Match_1874',
#  'Match_1877',
#  'Match_1878',
#  'Match_1989',
#  'Match_1990',
#  'Match_1994',
#  'Match_2013',
#  'Match_2030',
#  'Match_2031',
#  'Match_2034',
#  'Match_2036',
#  'Match_2041',
#  'Match_2048',
#  'Match_2049',
#  'Match_2060',
#  'Match_2062',
#  'Match_2084',
#  'Match_2088',
#  'Match_2099',
#  'Match_2100',
#  'Match_2146',
#  'Match_2147',
#  'Match_2148',
#  'Match_2149',
#  'Match_2150',
#  'Match_2151',
#  'Match_2152',
#  'Match_2154',
#  'Match_2158',
#  'Match_2159',
#  'Match_2160',
#  'Match_2161',
#  'Match_2164',
#  'Match_2166',
#  'Match_2181',
#  'Match_2184',
#  'Match_2238',
#  'Match_2239',
#  'Match_2240',
#  'Match_2241',
#  'Match_2242',
#  'Match_2243',
#  'Match_2244',
#  'Match_2246',
#  'Match_2252',
#  'Match_2253',
#  'Match_2254',
#  'Match_2257',
#  'Match_2261',
#  'Match_2265',
#  'Match_2267',
#  'Match_2298',
#  'Match_2299',
#  'Match_2300',
#  'Match_2301',
#  'Match_2302',
#  'Match_2303',
#  'Match_2305',
#  'Match_2307',
#  'Match_2309',
#  'Match_2312',
#  'Match_2313',
#  'Match_2317',
#  'Match_2324',
#  'Match_2325',
#  'Match_2338',
#  'Match_2364',
#  'Match_2369',
#  'Match_2371',
#  'Match_2372',
#  'Match_2373',
#  'Match_2374',
#  'Match_2377',
#  'Match_2378',
#  'Match_2379',
#  'Match_2385',
#  'Match_2392',
#  'Match_2393',
#  'Match_2394',
#  'Match_2403',
#  'Match_2441',
#  'Match_2442',
#  'Match_2444',
#  'Match_2445',
#  'Match_2446',
#  'Match_2448',
#  'Match_2450',
#  'Match_2453',
#  'Match_2462',
#  'Match_2498',
#  'Match_2500',
#  'Match_2505',
#  'Match_2506',
#  'Match_2507',
#  'Match_2508',
#  'Match_2510',
#  'Match_2511',
#  'Match_2533',
#  'Match_2534',
#  'Match_2535',
#  'Match_2536',
#  'Match_2537',
#  'Match_2538',
#  'Match_2587',
#  'Match_2588',
#  'Match_2589',
#  'Match_2590',
#  'Match_2591',
#  'Match_2592',
#  'Match_2594',
#  'Match_2595',
#  'Match_2596',
#  'Match_2598',
#  'Match_2599',
#  'Match_2600',
#  'Match_2602',
#  'Match_2604',
#  'Match_2605',
#  'Match_2608',
#  'Match_2609',
#  'Match_2611',
#  'Match_2893',
#  'Match_2894',
#  'Match_2896',
#  'Match_2898',
#  'Match_2899',
#  'Match_2900',
#  'Match_3129',
#  'Match_3130',
#  'Match_3131',
#  'Match_3132',
#  'Match_3134',
#  'Match_3143',
#  'Match_3144',
#  'Match_3146',
#  'Match_3160',
#  'Match_3274',
#  'Match_3287',
#  'Match_3326',
#  'Match_3327',
#  'Match_3328',
#  'Match_3329',
#  'Match_3331',
#  'Match_3332',
#  'Match_3334',
#  'Match_3342',
#  'Match_3343',
#  'Match_3344',
#  'Match_3345',
#  'Match_3346',
#  'Match_3347',
#  'Match_3348',
#  'Match_3349',
#  'Match_3363',
#  'Match_3401',
#  'Match_3431',
#  'Match_3464',
#  'Match_3465',
#  'Match_3466',
#  'Match_3467',
#  'Match_3468',
#  'Match_3474',
#  'Match_3475',
#  'Match_3476',
#  'Match_3477',
#  'Match_3478',
#  'Match_3481',
#  'Match_3482',
#  'Match_3483',
#  'Match_3485',
#  'Match_3486',
#  'Match_3489',
#  'Match_3504',
#  'Match_3509',
#  'Match_3515',
#  'Match_3615',
#  'Match_3616',
#  'Match_3617',
#  'Match_3618',
#  'Match_3621',
#  'Match_3637',
#  'Match_3645',
#  'Match_3668',
#  'Match_3669',
#  'Match_3674',
#  'Match_3724',
#  'Match_3725',
#  'Match_3730',
#  'Match_3731',
#  'Match_3732',
#  'Match_3733',
#  'Match_3772',
#  'Match_3773',
#  'Match_3774',
#  'Match_3775',
#  'Match_3776',
#  'Match_3781',
#  'Match_3782',
#  'Match_3788',
#  'Match_3789',
#  'Match_3801',
#  'Match_3826',
#  'Match_3853',
#  'Match_3859',
#  'Match_3860',
#  'Match_3866',
#  'Match_3867',
#  'Match_3868',
#  'Match_3870',
#  'Match_3872',
#  'Match_3884',
#  'Match_3910',
#  'Match_3911',
#  'Match_3916',
#  'Match_3917',
#  'Match_3918',
#  'Match_3921',
#  'Match_3936',
#  'Match_3941',
#  'Match_3944',
#  'Match_3983',
#  'Match_3984',
#  'Match_3987',
#  'Match_4001',
#  'Match_4004',
#  'Match_4012',
#  'Match_4015',
#  'Match_4024',
#  'Match_4026',
#  'Match_4062',
#  'Match_4063',
#  'Match_4069',
#  'Match_4080',
#  'Match_4088',
#  'Match_4161',
#  'Match_4162',
#  'Match_4163',
#  'Match_4164',
#  'Match_4165',
#  'Match_4166',
#  'Match_4167',
#  'Match_4168',
#  'Match_4169',
#  'Match_4172',
#  'Match_4173',
#  'Match_4174',
#  'Match_4176',
#  'Match_4178',
#  'Match_4192',
#  'Match_4199',
#  'Match_4319',
#  'Match_4320',
#  'Match_4324',
#  'Match_4326',
#  'Match_4327',
#  'Match_4337',
#  'Match_4338',
#  'Match_4341',
#  'Match_4342',
#  'Match_4344',
#  'Match_4345',
#  'Match_4352',
#  'Match_4361',
#  'Match_4362',
#  'Match_4363',
#  'Match_4373',
#  'Match_4436',
#  'Match_4437',
#  'Match_4438',
#  'Match_4443',
#  'Match_4445',
#  'Match_4449',
#  'Match_4532',
#  'Match_4709',
#  'Match_4710',
#  'Match_4714',
#  'Match_4717',
#  'Match_4736',
#  'Match_4902',
#  'Match_4903',
#  'Match_4904',
#  'Match_4905',
#  'Match_4906',
#  'Match_4907',
#  'Match_4908',
#  'Match_4913',
#  'Match_4915',
#  'Match_4917',
#  'Match_4918',
#  'Match_4935',
#  'Match_4937',
#  'Match_4968',
#  'Match_4970',
#  'Match_4978',
#  'Match_4979',
#  'Match_4984',
#  'Match_4985',
#  'Match_4996',
#  'Match_4997',
#  'Match_4998',
#  'Match_5008',
#  'Match_5010',
#  'Match_5016',
#  'Match_5039',
#  'Match_5040',
#  'Match_5041',
#  'Match_5044',
#  'Match_5045',
#  'Match_5046',
#  'Match_5048',
#  'Match_5049',
#  'Match_5050',
#  'Match_5051',
#  'Match_5053',
#  'Match_5055',
#  'Match_5056',
#  'Match_5251',
#  'Match_5263',
#  'Match_5272',
#  'Match_5276',
#  'Match_5284',
#  'Match_5285',
#  'Match_5333',
#  'Match_5336',
#  'Match_5339',
#  'Match_5399',
#  'Match_5405',
#  'Match_5406',
#  'Match_5431',
#  'Match_5474',
#  'Match_5475',
#  'Match_5477',
#  'Match_5487',
#  'Match_5496',
#  'Match_5507',
#  'Match_5516',
#  'Match_5518',
#  'Match_5520',
#  'Match_5581',
#  'Match_5582',
#  'Match_5583',
#  'Match_5724',
#  'Match_5725',
#  'Match_5737',
#  'Match_5739',
#  'Match_5749',
#  'Match_5750',
#  'Match_5752',
#  'Match_5765',
#  'Match_6028',
#  ...]

# %%
features = [c for c in train.columns if c not in ('id', 'y')]
assert(set(features) - set(test.columns.tolist()) == set())

# %%
discrete_features = [f for f in features if f not in categorical_features]
discrete_features
# Out:
# ['totalPitchingCount',
#  'B',
#  'S',
#  'O',
#  'b1',
#  'b2',
#  'b3',
#  'inningNo',
#  'numRunners',
#  'pitcherHoursElapsed',
#  'pitcherNumGamesParticipated',
#  'batterHoursElapsed',
#  'batterNumGamesParticipated',
#  'ballPositionLabel__no_data__',
#  'ど真ん中',
#  '内角中心',
#  '内角低め',
#  '内角高め',
#  '外角中心',
#  '外角低め',
#  '外角高め',
#  '真ん中低め',
#  '真ん中高め',
#  'ballPositionLabeld1',
#  'ballPositionLabeld2',
#  'ballPositionLabeld3',
#  'ballPositionLabeld4',
#  'ballPositionLabeld5',
#  'ballPositionLabeld6',
#  'ballPositionLabeld7',
#  'ballPositionLabeld8',
#  'ballPositionLabeld9',
#  'ballPositionLabeld10',
#  'ballPositionLabeld11',
#  'ballPositionLabeld12',
#  'ballPositionLabeld13',
#  'ballPositionLabeld14',
#  'ballPositionLabeld15',
#  'ballPositionLabeld16',
#  'ballPositionLabeld17',
#  'ballPositionLabeld18',
#  'ballPositionLabeld19',
#  'ballPositionLabeld20',
#  'ballPositionLabeld21',
#  'ballPositionLabeld22',
#  'ballPositionLabeld23',
#  'ballPositionLabeld24',
#  'ballPositionLabeld25',
#  'ballPositionLabeld26',
#  'ballPositionLabeld27',
#  'ballPositionLabeld28',
#  'ballPositionLabeld29',
#  'ballPositionLabeld30',
#  'ballPositionLabeld31',
#  'ballPositionLabeld32',
#  'ballPositionLabeld33',
#  'ballPositionLabeld34',
#  'ballPositionLabeld35',
#  'ballPositionLabeld36',
#  'ballPositionLabeld37',
#  'ballPositionLabeld38',
#  'ballPositionLabeld39',
#  'ballPositionLabeld40',
#  'ballPositionLabeld41',
#  'ballPositionLabeld42',
#  'ballPositionLabeld43',
#  'ballPositionLabeld44',
#  'ballPositionLabeld45',
#  'ballPositionLabeld46',
#  'ballPositionLabeld47',
#  'ballPositionLabeld48',
#  'ballPositionLabeld49',
#  'ballPositionLabeld50',
#  'pitchType__no_data__',
#  'カットファストボール',
#  'カーブ',
#  'シュート',
#  'シンカー',
#  'ストレート',
#  'スライダー',
#  'チェンジアップ',
#  'フォーク',
#  'pitchTyped1',
#  'pitchTyped2',
#  'pitchTyped3',
#  'pitchTyped4',
#  'pitchTyped5',
#  'pitchTyped6',
#  'pitchTyped7',
#  'pitchTyped8',
#  'pitchTyped9',
#  'pitchTyped10',
#  'pitchTyped11',
#  'pitchTyped12',
#  'pitchTyped13',
#  'pitchTyped14',
#  'pitchTyped15',
#  'pitchTyped16',
#  'pitchTyped17',
#  'pitchTyped18',
#  'pitchTyped19',
#  'pitchTyped20',
#  'pitchTyped21',
#  'pitchTyped22',
#  'pitchTyped23',
#  'pitchTyped24',
#  'pitchTyped25',
#  'pitchTyped26',
#  'pitchTyped27',
#  'pitchTyped28',
#  'pitchTyped29',
#  'pitchTyped30',
#  'pitchTyped31',
#  'pitchTyped32',
#  'pitchTyped33',
#  'pitchTyped34',
#  'pitchTyped35',
#  'pitchTyped36',
#  'pitchTyped37',
#  'pitchTyped38',
#  'pitchTyped39',
#  'pitchTyped40',
#  'pitchTyped41',
#  'pitchTyped42',
#  'pitchTyped43',
#  'pitchTyped44',
#  'pitchTyped45',
#  'pitchTyped46',
#  'pitchTyped47',
#  'pitchTyped48',
#  'pitchTyped49',
#  'pitchTyped50',
#  '10a',
#  '10b',
#  '10c',
#  '10d',
#  '10e',
#  '10f',
#  '10g',
#  '10h',
#  '10i',
#  '10j',
#  '10k',
#  '11a',
#  '11b',
#  '11c',
#  '11d',
#  '11e',
#  '11f',
#  '11g',
#  '11h',
#  '11i',
#  '11j',
#  '11k',
#  '12a',
#  '12b',
#  '12c',
#  '12d',
#  '12e',
#  '12f',
#  '12g',
#  '12h',
#  '12i',
#  '12j',
#  '12k',
#  '13a',
#  '13b',
#  '13c',
#  '13d',
#  '13e',
#  '13f',
#  '13g',
#  '13h',
#  '13i',
#  '13j',
#  '13k',
#  '14a',
#  '14b',
#  '14c',
#  '14d',
#  '14e',
#  '14f',
#  '14g',
#  '14h',
#  '14i',
#  '14j',
#  '14k',
#  '15a',
#  '15b',
#  '15c',
#  '15d',
#  '15e',
#  '15f',
#  '15g',
#  '15h',
#  '15i',
#  '15j',
#  '15k',
#  '16a',
#  '16b',
#  '16c',
#  '16d',
#  '16e',
#  '16f',
#  '16g',
#  '16h',
#  '16i',
#  '16j',
#  '16k',
#  '17a',
#  '17b',
#  '17c',
#  '17d',
#  '17e',
#  '17f',
#  '17g',
#  '17h',
#  '17i',
#  '17j',
#  '17k',
#  '18d',
#  '18e',
#  '18f',
#  '18g',
#  '18h',
#  '18i',
#  '18j',
#  '18k',
#  '19d',
#  '19e',
#  '19f',
#  '19g',
#  '19h',
#  '19i',
#  '19j',
#  '19k',
#  '1a',
#  '1b',
#  '1c',
#  '1d',
#  '1e',
#  '1f',
#  '1g',
#  '1h',
#  '1i',
#  '1j',
#  '1k',
#  '20a',
#  '20b',
#  '20d',
#  '20e',
#  '20f',
#  '20g',
#  '20h',
#  '20i',
#  '20j',
#  '20k',
#  '21a',
#  '21b',
#  '21c',
#  '21d',
#  '21e',
#  '21f',
#  '21g',
#  '21h',
#  '21i',
#  '21j',
#  '21k',
#  '2b',
#  '2d',
#  '2e',
#  '2f',
#  '2g',
#  '2h',
#  '2i',
#  '2j',
#  '2k',
#  '3b',
#  '3c',
#  '3d',
#  '3e',
#  '3f',
#  '3g',
#  '3h',
#  '3i',
#  '3j',
#  '3k',
#  '4b',
#  '4d',
#  '4e',
#  '4f',
#  '4g',
#  '4h',
#  '4i',
#  '4j',
#  '4k',
#  '5d',
#  '5e',
#  '5f',
#  '5g',
#  '5h',
#  '5i',
#  '5j',
#  '5k',
#  '6b',
#  '6d',
#  '6e',
#  '6f',
#  '6g',
#  '6h',
#  '6i',
#  '6j',
#  '6k',
#  '7a',
#  '7b',
#  '7c',
#  '7d',
#  '7e',
#  '7f',
#  '7g',
#  '7h',
#  '7i',
#  '7j',
#  '7k',
#  '8a',
#  '8b',
#  '8c',
#  '8d',
#  '8e',
#  '8f',
#  '8g',
#  '8h',
#  '8i',
#  '8j',
#  '8k',
#  '9a',
#  '9b',
#  '9c',
#  '9d',
#  '9e',
#  '9f',
#  '9g',
#  '9h',
#  '9i',
#  '9j',
#  '9k',
#  'ballXY__no_data__',
#  'ballXYd1',
#  'ballXYd2',
#  'ballXYd3',
#  'ballXYd4',
#  'ballXYd5',
#  'ballXYd6',
#  'ballXYd7',
#  'ballXYd8',
#  'ballXYd9',
#  'ballXYd10',
#  'ballXYd11',
#  'ballXYd12',
#  'ballXYd13',
#  'ballXYd14',
#  'ballXYd15',
#  'ballXYd16',
#  'ballXYd17',
#  'ballXYd18',
#  'ballXYd19',
#  'ballXYd20',
#  'ballXYd21',
#  'ballXYd22',
#  'ballXYd23',
#  'ballXYd24',
#  'ballXYd25',
#  'ballXYd26',
#  'ballXYd27',
#  'ballXYd28',
#  'ballXYd29',
#  'ballXYd30',
#  'ballXYd31',
#  'ballXYd32',
#  'ballXYd33',
#  'ballXYd34',
#  'ballXYd35',
#  'ballXYd36',
#  'ballXYd37',
#  'ballXYd38',
#  'ballXYd39',
#  'ballXYd40',
#  'ballXYd41',
#  'ballXYd42',
#  'ballXYd43',
#  'ballXYd44',
#  'ballXYd45',
#  'ballXYd46',
#  'ballXYd47',
#  'ballXYd48',
#  'ballXYd49',
#  'ballXYd50',
#  'speedcount',
#  'speedmean',
#  'speedstd',
#  'speedmin',
#  'speed25%',
#  'speed50%',
#  'speed75%',
#  'speedmax',
#  'speedrange',
#  'speedmeanDiff',
#  'speedstdDiff',
#  'speedminDiff',
#  'speed25%Diff',
#  'speed50%Diff',
#  'speed75%Diff',
#  'speedmaxDiff',
#  'pitchTypeRatioカットファストボール',
#  'pitchTypeRatioカーブ',
#  'pitchTypeRatioシュート',
#  'pitchTypeRatioシンカー',
#  'pitchTypeRatioストレート',
#  'pitchTypeRatioスライダー',
#  'pitchTypeRatioチェンジアップ',
#  'pitchTypeRatioフォーク',
#  'battersFaced',
#  'gameIDCount',
#  'numInningsSum',
#  'inningFromMin',
#  'inningFromMean',
#  'inningFromMedian',
#  'inningFromMax',
#  'inningFromStd',
#  'inningToMin',
#  'inningToMean',
#  'inningToMedian',
#  'inningToMax',
#  'inningToStd',
#  'pitcherNumStrikeOuts',
#  'pitcherNumWalks',
#  'hitsAllowed',
#  'K/9',
#  'BB/9',
#  'K1p/BB1p',
#  'whips',
#  'pitchersFaced',
#  'batterNumStrikeOuts',
#  'batterNumWalks',
#  'hits',
#  'battingTypeB',
#  'battingTypeF',
#  'battingTypeG',
#  'battingTypeL',
#  'battingTypeN',
#  'battingTypeP',
#  'distcount',
#  'distmean',
#  'diststd',
#  'distmin',
#  'dist25%',
#  'dist50%',
#  'dist75%',
#  'distmax',
#  'distrange',
#  'distcountDiff',
#  'distmeanDiff',
#  'diststdDiff',
#  'distminDiff',
#  'dist25%Diff',
#  'dist50%Diff',
#  'dist75%Diff',
#  'distmaxDiff',
#  'distDirA',
#  'distDirB',
#  'distDirC',
#  'distDirD',
#  'distDirE',
#  'distDirF',
#  'distDirG',
#  'distDirH',
#  'distDirI',
#  'distDirJ',
#  'distDirK',
#  'distDirL',
#  'distDirM',
#  'distDirN',
#  'distDirO',
#  'distDirP',
#  'distDirQ',
#  'distDirR',
#  'distDirS',
#  'distDirT',
#  'distDirU',
#  'distDirV',
#  'distDirW',
#  'distDirX',
#  'distDirY',
#  'distDirZ']

# %%
# %%time
splitter = StratifiedKFold(shuffle=True, random_state=SEED, n_splits=N)
cv_pred_dfs = []
pred_dfs = []
metrics = {'train': [], 'valid': []}
models = []
for i, (train_idx, valid_idx) in enumerate(splitter.split(train, train.y)):
    id_train, X_train, y_train, id_valid, X_valid, y_valid = (
        train.iloc[train_idx].id,
        train.iloc[train_idx][features],
        train.iloc[train_idx].y,
        train.iloc[valid_idx].id,
        train.iloc[valid_idx][features],
        train.iloc[valid_idx].y,
    )
    clf = get_estimator(categorical_features, discrete_features)
    clf.fit(X_train, y_train)
    models.append(clf)
    # Evaluate (trian set)
    pred_train = clf.predict(X_train)
    pred_train_df = pd.DataFrame(
        {
            'id': id_train,
            'actual': y_train,
            'prediction': pred_train,
        }
    )
    pred_train_df['train'] = 0
    print('*' * 10 + f'Confusion matrix for train set (Fold {i + 1})' + '*' * 10)
    print(confusion_matrix(y_train, pred_train))
    print()
    metrics['train'].append(f1_score(y_train, pred_train, average='macro'))
    # Evaluate (valid set)
    pred_valid = clf.predict(X_valid)
    pred_valid_df = pd.DataFrame(
        {
            'id': id_valid,
            'actual': y_valid,
            'prediction': pred_valid,
        }
    )
    pred_valid_df['train'] = 0
    print('*' * 10 + f'Confusion matrix for validation set (Fold {i + 1})' + '*' * 10)
    print(confusion_matrix(y_valid, pred_valid))
    print()
    metrics['valid'].append(f1_score(y_valid, pred_valid, average='macro'))
    # Save cv result
    cv_pred_df = pd.concat([pred_train_df, pred_valid_df], axis=0)
    cv_pred_df['fold'] = i + 1
    cv_pred_dfs.append(cv_pred_df)
    # Inference
    try:
        infer = clf.predict_proba(test[features].copy())
    except AttributeError:
        infer = clf.decision_function(test[features].copy())
    pred_df = pd.DataFrame(
        data=infer,
        columns=clf[-1].classes_
    )
    pred_df['id'] = test.id.values
    pred_df['fold'] = i + 1
    pred_dfs.append(pred_df)
# Out:
# **********Confusion matrix for train set (Fold 1)**********
# [[1650  380 1193  600  682  368    6  187]
#  [1015  579  744  500  561  220    4  123]
#  [ 352  213  969  307  353  125    1   73]
#  [ 141   90  385  599  288  125    0   81]
#  [  17   14  105   30  325   35    0   14]
#  [   2    4    9    2    1  131    0    1]
#  [   0    0    0    0    0    0    8    0]
#  [   0    0    0    0    0    0    0   96]]
#
# **********Confusion matrix for validation set (Fold 1)**********
# [[362  87 323 169 183  91   5  47]
#  [243 117 189 130 157  69   2  29]
#  [118  42 220  77  88  34   0  20]
#  [ 45  27  96  96  98  41   0  24]
#  [  9   3  35  20  40  18   0  10]
#  [  5   1   5   8  13   5   0   0]
#  [  0   0   2   0   0   0   0   1]
#  [  1   0   9   3   6   4   0   1]]
#
# **********Confusion matrix for train set (Fold 2)**********
# [[1797  324  992  921  463  358    8  203]
#  [1089  533  609  771  343  261    6  134]
#  [ 435  183  884  452  224  130    1   84]
#  [ 164   62  340  791  134  146    0   72]
#  [  25   15   93   78  280   32    0   17]
#  [   2    3    2    1    1  140    0    1]
#  [   0    0    0    0    0    0    9    0]
#  [   0    0    0    0    0    0    0   96]]
#
# **********Confusion matrix for validation set (Fold 2)**********
# [[430  65 286 230 119  83   4  50]
#  [278 116 167 210  87  51   2  25]
#  [145  53 173 129  53  22   1  23]
#  [ 56  26  90 135  59  37   0  24]
#  [ 19   6  34  37  19  13   0   7]
#  [  8   2   6  11   4   4   0   2]
#  [  1   0   0   0   0   1   0   0]
#  [  4   0   3   7   6   2   0   2]]
#
# **********Confusion matrix for train set (Fold 3)**********
# [[1809  335 1071  627  707  359    6  152]
#  [1087  562  681  525  540  253    6   92]
#  [ 440  204  903  325  316  134    1   71]
#  [ 167   92  376  577  315  114    0   67]
#  [  20   14  107   23  320   34    0   22]
#  [   0    1    7    0    1  141    0    0]
#  [   0    0    0    0    0    0    9    0]
#  [   0    0    1    0    0    0    0   95]]
#
# **********Confusion matrix for validation set (Fold 3)**********
# [[402 114 286 156 161 107   4  37]
#  [283 118 168 133 142  64   1  27]
#  [127  47 203  74  88  38   1  20]
#  [ 44  20  86 126  82  48   0  22]
#  [ 17   8  28  25  38  13   0   6]
#  [  4   2   7  10   7   5   0   2]
#  [  0   0   1   0   0   0   0   1]
#  [  3   0   1   2   7   7   0   4]]
#
# **********Confusion matrix for train set (Fold 4)**********
# [[1730  327 1117  822  543  341    9  178]
#  [1052  530  710  669  415  251    5  113]
#  [ 426  183  931  384  253  131    2   84]
#  [ 175   75  348  737  180  122    0   72]
#  [  26   14  101   59  291   31    0   18]
#  [   2    2    5    3    1  135    0    1]
#  [   0    0    0    0    0    0    9    0]
#  [   0    0    0    0    0    0    0   96]]
#
# **********Confusion matrix for validation set (Fold 4)**********
# [[399  83 279 202 147  92   0  64]
#  [244 124 185 193  98  52   3  38]
#  [127  57 180  98  83  33   0  20]
#  [ 39  19 104 144  72  30   0  19]
#  [ 16   3  28  40  25  14   0   9]
#  [  7   0   9   8   6   6   0   2]
#  [  0   0   1   1   0   0   0   0]
#  [  1   1   3   3   5   6   0   5]]
#
# **********Confusion matrix for train set (Fold 5)**********
# [[1771  338 1074  746  578  372   10  178]
#  [1092  559  667  570  471  273    7  106]
#  [ 444  204  921  335  283  139    1   67]
#  [ 160   78  358  688  209  141    0   75]
#  [  19   17  108   54  281   47    0   14]
#  [   1    2    4    1    0  140    0    1]
#  [   0    0    0    0    0    0    9    0]
#  [   0    0    1    0    0    0    0   95]]
#
# **********Confusion matrix for validation set (Fold 5)**********
# [[393 112 291 168 168  93   0  41]
#  [277 125 179 150 117  66   0  23]
#  [120  55 198  90  78  35   0  22]
#  [ 46  34  99 114  71  46   0  17]
#  [ 16   4  28  38  27  14   0   8]
#  [  7   1   5   6   6   8   0   5]
#  [  0   0   0   0   1   1   0   0]
#  [  5   1   4   6   1   3   0   4]]
#
# Wall time: 2h 41min 16s

# %%
metrics = pd.DataFrame(metrics).describe()
metrics.to_csv(os.path.join(OUTPUT_DIR, 'metrics.csv'))
metrics
# Out:
#           train     valid
# count  5.000000  5.000000
# mean   0.327331  0.157390
# std    0.003905  0.006687
# min    0.321188  0.150118
# 25%    0.326215  0.150951
# 50%    0.328356  0.159287
# 75%    0.329567  0.160938
# max    0.331327  0.165657

# %%
cv_results = pd.concat(cv_pred_dfs)
cv_results.to_csv(os.path.join(OUTPUT_DIR, 'cross_validation.csv'), index=False)
cv_results
# Out:
#           id  actual  prediction  train  fold
# 0          0       0           4      0     1
# 1          1       1           4      0     1
# 2          2       0           4      0     1
# 3          3       2           4      0     1
# 4          4       4           4      0     1
# ...      ...     ...         ...    ...   ...
# 17126   9690       0           1      0     5
# 17129   9693       1           1      0     5
# 17130  16833       1           1      0     5
# 17133   9762       1           1      0     5
# 17135   9764       1           1      0     5
#
# [85680 rows x 5 columns]

# %%
submission_ = pd.concat(pred_dfs)
submission_
# Out:
#               0         1         2         3         4         5         6  \
# 0      2.805710  1.820819  0.744350  5.266864  6.267184  4.230149 -0.291645
# 1      2.957956  3.069254  0.761942  7.272078  6.255179  4.192918 -0.293055
# 2      3.183533  5.225380  0.755983  7.260524  6.231567  3.096312 -0.293232
# 3      5.182925  4.215628  0.757981  7.262406  6.234775  2.075508 -0.293386
# 4      3.106547  4.212021  1.778323  7.266195  5.252225  6.232518 -0.293496
# ...         ...       ...       ...       ...       ...       ...       ...
# 33803  3.100556  7.297965  5.175419  6.291972  4.187646  2.136102 -0.297143
# 33804  2.816529  1.781763  0.745991  6.276179  5.243246  7.289022 -0.294213
# 33805  2.790814  1.767749  0.749312  6.277971  5.238981  7.290875 -0.294524
# 33806  4.146973  2.944340  0.743088  6.269610  5.222546  7.278305 -0.294008
# 33807  4.203817  4.218998  0.733955  6.252521  4.121370  7.274604 -0.294284
#
#               7     id  fold
# 0      7.239755  27446     1
# 1      4.121792    113     1
# 2      3.106778   4479     1
# 3      3.121280  29080     1
# 4      0.769365  19319     1
# ...         ...    ...   ...
# 33803  0.694930  24272     5
# 33804  3.941812  29106     5
# 33805  4.055610  20679     5
# 33806  1.829473  25901     5
# 33807  1.909576  12497     5
#
# [169040 rows x 10 columns]

# %%
submission_ = submission_.groupby('id')[[0, 1, 2, 3, 4, 5, 6, 7]].sum().sort_index().reset_index()
submission_
# Out:
#           id          0          1          2          3          4  \
# 0          0  25.124764  36.459406  22.007715  31.397537  15.562734
# 1          1  18.976815  20.072923   6.800727  33.321939  23.739175
# 2          2  14.092327   8.831897   4.031781  29.260496  34.377230
# 3          3  19.207520  26.250407  13.242079  36.450230  31.366415
# 4          4  15.902521  29.285924   8.749401  35.372323  20.798934
# ...      ...        ...        ...        ...        ...        ...
# 33803  33803  19.046514  11.126675   3.793816  21.876379  26.123681
# 33804  33804  17.887205  15.921854   3.696302  35.381991  21.862471
# 33805  33805  15.696582   9.148392   3.600954  24.118619  23.002240
# 33806  33806  10.786080  29.323838  18.086303  36.388518  27.305568
# 33807  33807  21.005155  16.728563   9.221223  32.332029  27.148971
#
#                5         6          7
# 0       9.703295 -1.492529   3.527336
# 1      34.251459 -1.478503   6.270873
# 2      24.066619 -1.462894  27.041442
# 3      11.395140 -1.483364   3.621795
# 4      29.127815 -1.461793   3.819619
# ...          ...       ...        ...
# 33803  33.290423 -1.481289  28.960064
# 33804  30.223881 -1.492290  19.281367
# 33805  31.239543 -1.462017  36.413215
# 33806  18.719082 -1.469500   3.518708
# 33807  33.238234 -1.469886   3.717532
#
# [33808 rows x 9 columns]

# %%
submission = pd.DataFrame(
    {
        'id': submission_.id,
        'y' : np.argmax(submission_[[0, 1, 2, 3, 4, 5, 6, 7]].values, axis=1)
    }
)
submission
# Out:
#           id  y
# 0          0  1
# 1          1  5
# 2          2  4
# 3          3  3
# 4          4  3
# ...      ... ..
# 33803  33803  5
# 33804  33804  3
# 33805  33805  7
# 33806  33806  3
# 33807  33807  5
#
# [33808 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.figure(figsize=(6., 5.))
fig.add_subplot(2, 1, 1)
sns.countplot(data=train, x='y')
fig.add_subplot(2, 1, 2)
sns.countplot(data=submission, x='y')
display(train.y.value_counts(normalize=True).sort_index())
display(submission.y.value_counts(normalize=True).sort_index())
# Out:
# 0    0.369573
# 1    0.273226
# 2    0.174603
# 3    0.124650
# 4    0.039391
# 5    0.010913
# 6    0.000642
# 7    0.007003
# Name: y, dtype: float64
# 0    0.045433
# 1    0.098497
# 2    0.000799
# 3    0.319924
# 4    0.038275
# 5    0.395794
# 7    0.101278
# Name: y, dtype: float64

# %%
submission.to_csv(os.path.join(OUTPUT_DIR, SUB_FILENAME), index=False)

# %%
metrics.loc['mean', 'train'], metrics.loc['mean', 'valid']
# Out:
# (0.3273306111526457, 0.15739023695743706)

# %%
print('"{}","{}","{:.6f}","{:.6f}","","{}"'.format(SUB_FILENAME, CV, metrics.loc['mean', 'train'], metrics.loc['mean', 'valid'], NOTE))
# Out:
# "014_submission.csv","Stratified-Kfold(K=5)","0.327331","0.157390","","全特徴量を使用したSVM. class_weight を指定。Cは0.1"

# %%
# %%time
for i, model in enumerate(models):
    with open(os.path.join(OUTPUT_DIR, f'model_fold{i + 1}.pickle'), 'wb') as f:
        pickle.dump(model, f)
        f.close()
# Out:
# Wall time: 2.54 s
